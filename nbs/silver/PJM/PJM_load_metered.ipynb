# %%
import pandas as pd
from usagrid import s3

df = s3.read_pyarrow_from_s3(bucket_name="usagrid",key="silver/PJM/PJM_load_metered.arrow").to_pandas()

# %%
df
# Out:
#                        datetime_beginning_ept nerc_region mkt_region  zone  \
# datetime_beginning_utc
# 2018-01-01 05:00:00       2018-01-01 00:00:00         RFC       WEST   DAY
# 2018-01-01 05:00:00       2018-01-01 00:00:00         RFC     MIDATL    AE
# 2018-01-01 05:00:00       2018-01-01 00:00:00         RFC       WEST   AEP
# 2018-01-01 05:00:00       2018-01-01 00:00:00         RFC       WEST   AEP
# 2018-01-01 05:00:00       2018-01-01 00:00:00         RFC       WEST   AEP
# ...                                       ...         ...        ...   ...
# 2024-06-18 03:00:00       2024-06-17 23:00:00         RFC     MIDATL  RECO
# 2024-06-18 03:00:00       2024-06-17 23:00:00         RFC     MIDATL   PEP
# 2024-06-18 03:00:00       2024-06-17 23:00:00         RFC     MIDATL    AE
# 2024-06-18 03:00:00       2024-06-17 23:00:00         RFC     MIDATL   DPL
# 2024-06-18 03:00:00       2024-06-17 23:00:00         RTO        RTO   RTO
#
# ...
